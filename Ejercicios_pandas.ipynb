# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloDiosquez/Algoritmos_Y_Programacion_UBA/blob/main/Ejercicios_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
peliculas = {'nombre': ['Titanic', 'Kil Bill', 'Matrix', 'El padrino', 'Avatar',
                        'Casablanca', 'El exorcista',  'Soy leyenda',
                        'El club de la pelea', 'Mujercitas'],
            'director': ['James Cameron', 'Quentin Tarantino', 'Hermanas Wachowski',
                        'Francis Ford Coppola', 'James Cameron', 'Michael Curtiz',
                        'William Friedkin', 'Francis Lawrence','David Fincher',
                        'Greta Gerwig'],
            'año': [1997, 2003, 1999, 1972, 2009, 1942, 1973, 2007, 1999, 2019],
            'género': ['romance', 'acción', 'ciencia ficción', 'drama', 'ciencia ficción', 'drama', 'terror',
                        'ciencia ficción', 'drama', 'drama'],
            'puntaje': [8.6, None, 6.9, 7.5, 9.1, 6.0, None, None, 9.4, 8.0]}

df = pd.DataFrame(peliculas)
df
# Out:
#                 nombre              director   año           género  puntaje
# 0              Titanic         James Cameron  1997          romance      8.6
# 1             Kil Bill     Quentin Tarantino  2003           acción      NaN
# 2               Matrix    Hermanas Wachowski  1999  ciencia ficción      6.9
# 3           El padrino  Francis Ford Coppola  1972            drama      7.5
# 4               Avatar         James Cameron  2009  ciencia ficción      9.1
# 5           Casablanca        Michael Curtiz  1942            drama      6.0
# 6         El exorcista      William Friedkin  1973           terror      NaN
# 7          Soy leyenda      Francis Lawrence  2007  ciencia ficción      NaN
# 8  El club de la pelea         David Fincher  1999            drama      9.4
# 9           Mujercitas          Greta Gerwig  2019            drama      8.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   nombre    10 non-null     object
#  1   director  10 non-null     object
#  2   año       10 non-null     int64
#  3   género    10 non-null     object
#  4   puntaje   7 non-null      float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 528.0+ bytes

# %%
df.iloc[3:]
# Out:
#                 nombre              director   año           género  puntaje
# 3           El padrino  Francis Ford Coppola  1972            drama      7.5
# 4               Avatar         James Cameron  2009  ciencia ficción      9.1
# 5           Casablanca        Michael Curtiz  1942            drama      6.0
# 6         El exorcista      William Friedkin  1973           terror      NaN
# 7          Soy leyenda      Francis Lawrence  2007  ciencia ficción      NaN
# 8  El club de la pelea         David Fincher  1999            drama      9.4
# 9           Mujercitas          Greta Gerwig  2019            drama      8.0

# %%
df.describe()
# Out:
#                año   puntaje
# count    10.000000  7.000000
# mean   1992.000000  7.928571
# std      22.968578  1.221630
# min    1942.000000  6.000000
# 25%    1979.000000  7.200000
# 50%    1999.000000  8.000000
# 75%    2006.000000  8.850000
# max    2019.000000  9.400000

# %%
# Mostrar la información del DataFrame con el método info(), ¿Cómo se llaman y qué tipo de dato tiene cada columna?
# ¿Cuántos elementos nulos hay en cada columna? Interpretar qué información se guarda en esta tabla y para qué puede servir.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   nombre    10 non-null     object
#  1   director  10 non-null     object
#  2   año       10 non-null     int64
#  3   género    10 non-null     object
#  4   puntaje   7 non-null      float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 528.0+ bytes

# %%
# Mostrar sólo los nombres de las primeras 3 películas del DataFrame.
# df.head(3)['nombre']
# df.iloc[:3]['nombre']
df.loc[:2, ['nombre']]
# Out:
#      nombre
# 0   Titanic
# 1  Kil Bill
# 2    Matrix

# %%
# Mostrar sólo el director y el género de todas las películas.
# df.loc[:, ['director', 'género']]
df[['director', 'género']]
# Out:
#                director           género
# 0         James Cameron          romance
# 1     Quentin Tarantino           acción
# 2    Hermanas Wachowski  ciencia ficción
# 3  Francis Ford Coppola            drama
# 4         James Cameron  ciencia ficción
# 5        Michael Curtiz            drama
# 6      William Friedkin           terror
# 7      Francis Lawrence  ciencia ficción
# 8         David Fincher            drama
# 9          Greta Gerwig            drama

# %%
 # Mostrar las películas que sean de drama
df[df['género'] == 'drama'][['nombre', 'director']]
# Out:
#                 nombre              director
# 3           El padrino  Francis Ford Coppola
# 5           Casablanca        Michael Curtiz
# 8  El club de la pelea         David Fincher
# 9           Mujercitas          Greta Gerwig

# %%
# ¿Qué cantidad de películas hay de cada género?

df['género'].value_counts()

df.groupby('género')[['género']].count()
# Out:
#                  género
# género
# acción                1
# ciencia ficción       3
# drama                 4
# romance               1
# terror                1

# %%
# Mostrar las películas que tengan puntaje entre 6 y 8 y cuyo año de estreno sea
# anterior a los 2000

# df[(df['puntaje'] >= 6) & (df['puntaje'] <= 8) & (df['año'] < 2000)]

df[df['puntaje'].between(6,8)][df['año'] < 2000]
# Out:
# <ipython-input-40-afe8f3a31bdb>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['puntaje'].between(6,8)][df['año'] < 2000]
#        nombre              director   año           género  puntaje
# 2      Matrix    Hermanas Wachowski  1999  ciencia ficción      6.9
# 3  El padrino  Francis Ford Coppola  1972            drama      7.5
# 5  Casablanca        Michael Curtiz  1942            drama      6.0

# %%
# Mostrar las películas que no hayan sido puntuadas (que el puntaje tenga un valor nulo).

df[df['puntaje'].isnull()][['nombre', 'director', 'género']]
# Out:
#          nombre           director           género
# 1      Kil Bill  Quentin Tarantino           acción
# 6  El exorcista   William Friedkin           terror
# 7   Soy leyenda   Francis Lawrence  ciencia ficción

# %%
# Calcular el promedio del puntaje de todas las películas.

print(f"El promedio del puntaje de todas las películas es {df['puntaje'].mean().round(2)}")
# Out:
# El promedio del puntaje de todas las películas es 7.93

# %%
# Ordenar las películas en orden alfabético descendente.

df.sort_values(by=['nombre'], ascending=False)
# Out:
#                 nombre              director   año           género  puntaje
# 0              Titanic         James Cameron  1997          romance      8.6
# 7          Soy leyenda      Francis Lawrence  2007  ciencia ficción      NaN
# 9           Mujercitas          Greta Gerwig  2019            drama      8.0
# 2               Matrix    Hermanas Wachowski  1999  ciencia ficción      6.9
# 1             Kil Bill     Quentin Tarantino  2003           acción      NaN
# 3           El padrino  Francis Ford Coppola  1972            drama      7.5
# 6         El exorcista      William Friedkin  1973           terror      NaN
# 8  El club de la pelea         David Fincher  1999            drama      9.4
# 5           Casablanca        Michael Curtiz  1942            drama      6.0
# 4               Avatar         James Cameron  2009  ciencia ficción      9.1

# %%
# Mostrar las 3 películas más antiguas.

df.sort_values(by=['año'], ascending=True).head(3)
# Out:
#          nombre              director   año  género  puntaje
# 5    Casablanca        Michael Curtiz  1942   drama      6.0
# 3    El padrino  Francis Ford Coppola  1972   drama      7.5
# 6  El exorcista      William Friedkin  1973  terror      NaN

# %%
# Mostrar sólo el nombre y el año de las 3 películas más nuevas.

df.sort_values(by=['año'], ascending=False)[['nombre', 'año']].head(3)
# Out:
#         nombre   año
# 9   Mujercitas  2019
# 4       Avatar  2009
# 7  Soy leyenda  2007

# %%
# Agregar una columna que indique si la película fue vista, o no.
# Una película fue vista cuando tiene puntaje no nulo.

df['vista'] = df['puntaje'].notna()
df['vista'] = df['vista'].map({True: 'Si', False: 'No'})
df
# Out:
#                 nombre              director   año           género  puntaje  \
# 0              Titanic         James Cameron  1997          romance      8.6
# 1             Kil Bill     Quentin Tarantino  2003           acción      NaN
# 2               Matrix    Hermanas Wachowski  1999  ciencia ficción      6.9
# 3           El padrino  Francis Ford Coppola  1972            drama      7.5
# 4               Avatar         James Cameron  2009  ciencia ficción      9.1
# 5           Casablanca        Michael Curtiz  1942            drama      6.0
# 6         El exorcista      William Friedkin  1973           terror      NaN
# 7          Soy leyenda      Francis Lawrence  2007  ciencia ficción      NaN
# 8  El club de la pelea         David Fincher  1999            drama      9.4
# 9           Mujercitas          Greta Gerwig  2019            drama      8.0
#
#   vista
# 0    Si
# 1    No
# 2    Si
# 3    Si
# 4    Si
# 5    Si
# 6    No
# 7    No
# 8    Si
# 9    Si
