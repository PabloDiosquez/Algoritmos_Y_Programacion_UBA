# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloDiosquez/Algoritmos_Y_Programacion_UBA/blob/main/Python_Pandas_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('weather_data.csv')
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
rows, cols = df.shape
print(rows)
print(cols)
# Out:
# 6
# 4

# %%
df.head(3)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df.tail(3)
# Out:
#         day  temperature  windspeed  event
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
# df['day']
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
type(df['event'])
# Out:
# pandas.core.series.Series

# %%
df[['day', 'event', 'temperature']]
# Out:
#         day  event  temperature
# 0  1/1/2017   Rain           32
# 1  1/2/2017  Sunny           35
# 2  1/3/2017   Snow           28
# 3  1/4/2017   Snow           24
# 4  1/5/2017   Rain           32
# 5  1/6/2017  Sunny           31

# %%
print(df['temperature'].max())
print(df['temperature'].min())
print(df['temperature'].mean())
print(df['temperature'].std())
# Out:
# 35
# 24
# 30.333333333333332
# 3.8297084310253524

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
df[df['temperature'] >= 29][['day', 'temperature', 'event']]
# Out:
#         day  temperature  event
# 0  1/1/2017           32   Rain
# 1  1/2/2017           35  Sunny
# 4  1/5/2017           32   Rain
# 5  1/6/2017           31  Sunny
